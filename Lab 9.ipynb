# %% [markdown]
# ### Lab 9
#
# #### Recursion in Python
#
# The term Recursion can be defined as the process of defining something in terms of itself. In simple words, it is a process in which a function calls itself directly or indirectly.
#
# ![image.png](attachment:image.png)
#
#  1. A complicated function can be split down into smaller sub-problems utilizing recursion.
#  2. Sequence creation is simpler through recursion than utilizing any nested iteration.
#  2. Recursive functions render the code look simple and effective.
#
# Disadvantages of using recursion
#
#  1. A lot of memory and time is taken through recursive calls which makes it expensive for use.
#  2. Recursive functions are challenging to debug.
#  3. The reasoning behind recursion can sometimes be tough to think through.

# %%
# Example of a recursive function
def factorial(x):
#This is a recursive function to find the factorial of an integer
    if x == 1:
        return 1
    else:
        return (x * factorial(x-1))


num = 6
print("The factorial of", num, "is", factorial(num))
# Out:
# The factorial of 6 is 720

# %% [markdown]
# **Question 1**. A Fibonacci sequence is the integer sequence of 0, 1, 1, 2, 3, 5, 8 .... using a recursive function, print the fibonacci series upto n_terms.

# %%
# Recursive function
def fibonacci(n):
  if n <= 1:
      ...
  else:
      ...
 
n = 20
if n <= 0:
  print("Invalid input ! Please input a positive value")
else:
  print("Fibonacci series:")
for i in range(n):
    print(fibonacci(i))
# Out:
# Fibonacci series:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %% [markdown]
# #### Binary Search
# In a nutshell, this search algorithm takes advantage of a collection of elements that is already sorted by ignoring half of the elements after just one comparison.
#
# Compare x with the middle element.
#  1. If x matches with the middle element, we return the mid index.
#  2. Else if x is greater than the mid element, then x can only lie in the right (greater) half subarray after the
#     mid element. Then we apply the algorithm again for the right half.
#  3. Else if x is smaller, the target x must lie in the left (lower) half. So we apply the algorithm for the left
#     half.

# %%
#RECURSIVE EXAMPLE
# Returns index of x in arr if present, else -1
def binary_search(arr, low, high, x):
 
    # Check base case
    if high >= low:
 
        mid = (high + low) // 2
 
        # If element is present at the middle itself
        if arr[mid] == x:
            return mid
 
        # If element is smaller than mid, then it can only
        # be present in left subarray
        elif arr[mid] > x:
            return binary_search(arr, low, mid - 1, x)
 
        # Else the element can only be present in right subarray
        else:
            return binary_search(arr, mid + 1, high, x)
 
    else:
        # Element is not present in the array
        return -1
 
# Test array
arr = [ 2, 3, 4, 10, 40 ]
x = 10
 
# Function call
result = binary_search(arr, 0, len(arr)-1, x)
 
if result != -1:
    print("Element is present at index", str(result))
else:
    print("Element is not present in array")
# Out:
# Element is present at index 3

# %% [markdown]
# **Question 2**. Implement binary search using iterative function

# %%
def binary_search(arr, x):
    low = 0
    high = len(arr) - 1
    mid = 0
 
    while low <= high:
 
        ...
 
        # If x is greater, ignore left half
        if arr[mid] < x:
            ...
 
        # If x is smaller, ignore right half
        elif arr[mid] > x:
            ...
 
        # means x is present at mid
        else:
            ...
 
    # If we reach here, then the element was not present
    return -1
 
    
arr = [ 2, 3, 4, 10, 40 ]
x = 10
 
# Function call
result = binary_search(arr, x)
 
if result != -1:
    print("Element is present at index", str(result))
else:
    print("Element is not present in array")

# %% [markdown]
# **Question 3** Sort the array [10, 5, 12, 7, 9, 12, 4]  Using Bubble sort, Selection Sort or Insertion Sort

# %%
arr = ...
def sort_array(arr):
    ...
    ...
    ...
